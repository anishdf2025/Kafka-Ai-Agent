# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Kafka Topics/Concepts We Discussed
#
# About Apache Kafka
#
# ---
#
# # Basics
#
# 1. What is Kafka
# 2. Why Kafka is used
# 3. Problems Kafka solves
# 4. Event
# 5. Streaming
# 6. Distributed system
# 7. Real-time processing
# 8. Asynchronous communication
#
# ---
#
# # Core Kafka Components
#
# 9. Producer
# 10. Consumer
# 11. Topic
# 12. Broker
# 13. Kafka Cluster
# 14. Partition
# 15. Offset
# 16. Consumer Group
#
# ---
#
# # Message Processing
#
# 17. Poll (`poll()`)
# 18. Heartbeat
# 19. `heartbeat.interval.ms`
# 20. `session.timeout.ms`
# 21. `max.poll.interval.ms`
# 22. Manual Commit
# 23. Auto Commit
# 24. Offset Commit
# 25. Offset Tracking
# 26. Offset Replay
#
# ---
#
# # Consumer Group Internals
#
# 27. Rebalancing
# 28. Group Coordinator
# 29. Partition Assignment
# 30. One Partition → One Consumer Rule
# 31. Consumer Failover
# 32. Parallel Processing
# 33. Worker Thread Model
# 34. Blocking Consumer Model
#
# ---
#
# # Reliability & Fault Tolerance
#
# 35. Replication
# 36. Replication Factor
# 37. Leader Broker
# 38. Follower Broker
# 39. Leader Election
# 40. ISR (In Sync Replica)
# 41. Fault Tolerance
#
# ---
#
# # Producer Concepts
#
# 42. `acks=0`
# 43. `acks=1`
# 44. `acks=all`
# 45. Idempotency
# 46. Exactly Once Semantics
#
# ---
#
# # Message Ordering & Parallelism
#
# 47. Ordering Guarantee
# 48. Key-Based Partitioning
# 49. Partition Key
# 50. Hot Partition Problem
# 51. Throughput
# 52. Batch Processing
#
# ---
#
# # Storage Concepts
#
# 53. Retention
# 54. Log Compaction
# 55. Replay Messages
#
# ---
#
# # Performance & Monitoring
#
# 56. Consumer Lag
# 57. Backpressure
# 58. Autoscaling Consumers
# 59. Compression
# 60. Polling Frequency
#
# ---
#
# # Failure Handling
#
# 61. Retry Mechanism
# 62. Retry Topic
# 63. DLQ (Dead Letter Queue)
# 64. Message Redelivery
#
# ---
#
# # Serialization
#
# 65. Serialization
# 66. Deserialization
# 67. Schema Registry
#
# ---
#
# # Kafka Ecosystem
#
# 68. Kafka Connect
# 69. Kafka Streams
# 70. Apache Spark
# 71. Apache Flink
# 72. Debezium
# 73. CDC (Change Data Capture)
#
# ---
#
# # Architecture/Design Patterns
#
# 74. Event-Driven Architecture
# 75. Pub/Sub Model
# 76. Queue Model
# 77. Scheduler vs Kafka
# 78. Polling vs Streaming
# 79. Microservices Communication
#
# ---
#
# # Production/Monitoring Tools
#
# 80. Prometheus
# 81. Grafana
# 82. Burrow
